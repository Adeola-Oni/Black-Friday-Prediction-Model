# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv("BlackFriday.csv")
X = dataset.iloc[:,2:11].values
Y = dataset.iloc[:,11:].values

# %%
import seaborn as sns
sns.barplot(x="Age", y="Purchase", data=dataset)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x="Gender", y="Purchase", data=dataset)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(dataset['Age'],hue=dataset['Gender'])

# %%
sns.barplot(x="Occupation", y="Purchase", data=dataset)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x = "City_Category", y="Purchase", data=dataset)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x = "Marital_Status", y="Purchase", data=dataset)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(dataset['City_Category'],hue=dataset['Marital_Status'])

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values="NaN", strategy="mean", axis = 0)
imputer = imputer.fit(X[:,7:9])
X[:,7:9] = imputer.transform(X[:,7:9])

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelEncoder_x = LabelEncoder()
X[:,0] = labelEncoder_x.fit_transform(X[:,0])
X[:,1] = labelEncoder_x.fit_transform(X[:,1])
X[:,3] = labelEncoder_x.fit_transform(X[:,3])
X[:,4] = labelEncoder_x.fit_transform(X[:,4])
onehotencoder = OneHotEncoder(categorical_features = [0,1,3,4])
X = onehotencoder.fit_transform(X).toarray()

# %%
x_raw = np.asarray(X)
x_raw.shape
# Out:
# (537577, 22)

# %%
y_raw = np.asarray(Y)
y_raw.shape
# Out:
# (537577, 1)

# %%
def featureNorm(X):
    # save the feature data in another variable
    x_norm = X.copy()
    
    # Create a row vector of zeros, having the same number of rows as the input feature
    mean = np.mean(X, axis=0)
    standard_deviation = np.std(X, axis=0)
    print("mean  is", mean , "\n")
    print("standard_deviation  is", standard_deviation , "\n")
    
    # The formula
    x_norm = np.divide((X - mean),standard_deviation)
    print("... Input feature has been normalized", "\n")
    
    # Now, we can add the one vector that represent the coefficent of the bias that we discussed earlier
    x = np.concatenate((np.ones((X[:,0].size, 1)), x_norm), axis=1) 
    print("... A ones vector has been successfully concatenated to the input feature matrix", "\n")
    
    return x, mean, standard_deviation

# %%
x, mean, standard_deviation = featureNorm(X)
# Out:
# mean  is [ 0.24591268  0.75408732  0.02735794  0.18161863  0.39936604  0.19996949
#   0.0828272   0.06997695  0.03888373  0.26905541  0.42132197  0.30962262
#   0.13528295  0.3519347   0.1850135   0.17357885  0.15419     8.08271001
#   0.40879725  5.2955465   9.84214403 12.66984015]
#
# standard_deviation  is [0.43062702 0.43062702 0.16312414 0.3855299  0.48976812 0.39997712
#  0.27562086 0.25510817 0.19331784 0.44346882 0.49377097 0.46233803
#  0.34202554 0.47757373 0.38830851 0.37874693 0.36113079 6.5241137
#  0.49161169 3.75069746 4.22386832 2.27993575]
#
# ... Input feature has been normalized
#
# ... A ones vector has been successfully concatenated to the input feature matrix

# %%
x
# Out:
# array([[ 1.00000000e+00,  1.75113795e+00, -1.75113795e+00, ...,
#         -6.12031901e-01, -3.21301831e-13,  2.93442162e-11],
#        [ 1.00000000e+00,  1.75113795e+00, -1.75113795e+00, ...,
#         -1.14526606e+00, -9.09626851e-01,  5.83419883e-01],
#        [ 1.00000000e+00,  1.75113795e+00, -1.75113795e+00, ...,
#          1.78752181e+00, -3.21301831e-13,  2.93442162e-11],
#        ...,
#        [ 1.00000000e+00, -5.71057238e-01,  5.71057238e-01, ...,
#          7.21053492e-01,  1.22112139e+00,  2.93442162e-11],
#        [ 1.00000000e+00, -5.71057238e-01,  5.71057238e-01, ...,
#         -7.87977440e-02, -3.21301831e-13,  2.93442162e-11],
#        [ 1.00000000e+00, -5.71057238e-01,  5.71057238e-01, ...,
#         -7.87977440e-02, -4.36127241e-01,  2.93442162e-11]])

# %%
def train(x, Y):
    iteration = 1000
    # For this practice are initiallizing are theta with values of zero.
    theta = np.zeros((23, 1))
    
    # Here, want to save our cost function or loss or square error, 
    # so that we can have an idea of how the deviation of the hypothesis from the ground thruth reduces
    cost_function = np.zeros(iteration)
    
    for i in range(iteration):
        # Step 1: we make a prediction using the random weights (theta) that we initialized
        # @ is a fancy way do performing dot products
        h = x @ theta
        # Step 2: We take a step to correct the weights (theta) to that the next predicion will be better
        theta = update_weight(h, theta, x)
        # Step 3: We measure the deviation or error
        cost_function[i] = cost(x, theta)

        print("Running Gradient Descent. Current cost function is ", np.log(cost_function[i]))
        
    return theta, cost_function

# %%
def cost(x, theta):
    m = x[:,0].size
    h = x @ theta
    return (1/2*m) * np.sum(np.square(h - Y))

# %%
def update_weight(h, theta, x):
    m = x[:,0].size
    alpha = 0.01
    theta = theta - alpha * (1/m * (x.T @ (h - Y)))
    return theta

# %%
theta, cost_values = train(x, Y)
# Out:
# Running Gradient Descent. Current cost function is  44.21363525112111
# Running Gradient Descent. Current cost function is  44.19743415022202
# Running Gradient Descent. Current cost function is  44.18130223968651
# Running Gradient Descent. Current cost function is  44.16524026203833
# Running Gradient Descent. Current cost function is  44.14924896052796
# Running Gradient Descent. Current cost function is  44.133329078805815
# Running Gradient Descent. Current cost function is  44.117481360588386
# Running Gradient Descent. Current cost function is  44.101706549317385
# Running Gradient Descent. Current cost function is  44.08600538781208
# Running Gradient Descent. Current cost function is  44.07037861791492
# Running Gradient Descent. Current cost function is  44.05482698013075
# Running Gradient Descent. Current cost function is  44.039351213259756
# Running Gradient Descent. Current cost function is  44.023952054024356
# Running Gradient Descent. Current cost function is  44.00863023669029
# Running Gradient Descent. Current cost function is  43.993386492682156
# Running Gradient Descent. Current cost function is  43.97822155019373
# Running Gradient Descent. Current cost function is  43.963136133793164
# Running Gradient Descent. Current cost function is  43.94813096402364
# Running Gradient Descent. Current cost function is  43.93320675699954
# Running Gradient Descent. Current cost function is  43.91836422399864
# Running Gradient Descent. Current cost function is  43.903604071050566
# Running Gradient Descent. Current cost function is  43.888926998522024
# Running Gradient Descent. Current cost function is  43.87433370069893
# Running Gradient Descent. Current cost function is  43.859824865366136
# Running Gradient Descent. Current cost function is  43.84540117338498
# Running Gradient Descent. Current cost function is  43.83106329826906
# Running Gradient Descent. Current cost function is  43.81681190575879
# Running Gradient Descent. Current cost function is  43.802647653395155
# Running Gradient Descent. Current cost function is  43.788571190093
# Running Gradient Descent. Current cost function is  43.77458315571454
# Running Gradient Descent. Current cost function is  43.76068418064339
# Running Gradient Descent. Current cost function is  43.746874885359695
# Running Gradient Descent. Current cost function is  43.73315588001688
# Running Gradient Descent. Current cost function is  43.719527764020484
# Running Gradient Descent. Current cost function is  43.705991125609586
# Running Gradient Descent. Current cost function is  43.69254654144144
# Running Gradient Descent. Current cost function is  43.679194576179746
# Running Gradient Descent. Current cost function is  43.66593578208715
# Running Gradient Descent. Current cost function is  43.6527706986225
# Running Gradient Descent. Current cost function is  43.63969985204336
# Running Gradient Descent. Current cost function is  43.62672375501445
# Running Gradient Descent. Current cost function is  43.61384290622239
# Running Gradient Descent. Current cost function is  43.60105778999735
# Running Gradient Descent. Current cost function is  43.588368875942216
# Running Gradient Descent. Current cost function is  43.57577661856975
# Running Gradient Descent. Current cost function is  43.563281456948175
# Running Gradient Descent. Current cost function is  43.550883814355934
# Running Gradient Descent. Current cost function is  43.53858409794589
# Running Gradient Descent. Current cost function is  43.52638269841968
# Running Gradient Descent. Current cost function is  43.514279989712534
# Running Gradient Descent. Current cost function is  43.502276328689234
# Running Gradient Descent. Current cost function is  43.490372054851484
# Running Gradient Descent. Current cost function is  43.47856749005735
# Running Gradient Descent. Current cost function is  43.466862938253016
# Running Gradient Descent. Current cost function is  43.45525868521742
# Running Gradient Descent. Current cost function is  43.44375499832013
# Running Gradient Descent. Current cost function is  43.432352126292855
# Running Gradient Descent. Current cost function is  43.4210502990149
# Running Gradient Descent. Current cost function is  43.40984972731305
# Running Gradient Descent. Current cost function is  43.39875060277607
# Running Gradient Descent. Current cost function is  43.387753097584145
# Running Gradient Descent. Current cost function is  43.37685736435368
# Running Gradient Descent. Current cost function is  43.366063535997505
# Running Gradient Descent. Current cost function is  43.355371725600854
# Running Gradient Descent. Current cost function is  43.34478202631328
# Running Gradient Descent. Current cost function is  43.334294511256715
# Running Gradient Descent. Current cost function is  43.32390923344975
# Running Gradient Descent. Current cost function is  43.31362622574832
# Running Gradient Descent. Current cost function is  43.303445500802916
# Running Gradient Descent. Current cost function is  43.29336705103227
# Running Gradient Descent. Current cost function is  43.28339084861371
# Running Gradient Descent. Current cost function is  43.27351684549006
# Running Gradient Descent. Current cost function is  43.26374497339314
# Running Gradient Descent. Current cost function is  43.25407514388382
# Running Gradient Descent. Current cost function is  43.24450724840849
# Running Gradient Descent. Current cost function is  43.23504115837196
# Running Gradient Descent. Current cost function is  43.22567672522649
# Running Gradient Descent. Current cost function is  43.21641378057698
# Running Gradient Descent. Current cost function is  43.20725213630199
# Running Gradient Descent. Current cost function is  43.19819158469046
# Running Gradient Descent. Current cost function is  43.18923189859384
# Running Gradient Descent. Current cost function is  43.18037283159344
# Running Gradient Descent. Current cost function is  43.17161411818258
# Running Gradient Descent. Current cost function is  43.16295547396348
# Running Gradient Descent. Current cost function is  43.15439659585817
# Running Gradient Descent. Current cost function is  43.14593716233351
# Running Gradient Descent. Current cost function is  43.1375768336396
# Running Gradient Descent. Current cost function is  43.129315252061325
# Running Gradient Descent. Current cost function is  43.121152042182665
# Running Gradient Descent. Current cost function is  43.11308681116324
# Running Gradient Descent. Current cost function is  43.10511914902669
# Running Gradient Descent. Current cost function is  43.09724862896046
# Running Gradient Descent. Current cost function is  43.089474807626395
# Running Gradient Descent. Current cost function is  43.081797225481914
# Running Gradient Descent. Current cost function is  43.074215407110884
# Running Gradient Descent. Current cost function is  43.066728861564044
# Running Gradient Descent. Current cost function is  43.05933708270825
# Running Gradient Descent. Current cost function is  43.05203954958408
# Running Gradient Descent. Current cost function is  43.044835726771296
# Running Gradient Descent. Current cost function is  43.03772506476154
# Running Gradient Descent. Current cost function is  43.030707000337806
# Running Gradient Descent. Current cost function is  43.02378095696014
# Running Gradient Descent. Current cost function is  43.01694634515693
# Running Gradient Descent. Current cost function is  43.010202562921414
# Running Gradient Descent. Current cost function is  43.003548996112656
# Running Gradient Descent. Current cost function is  42.99698501886061
# Running Gradient Descent. Current cost function is  42.99050999397471
# Running Gradient Descent. Current cost function is  42.98412327335535
# Running Gradient Descent. Current cost function is  42.977824198407845
# Running Gradient Descent. Current cost function is  42.97161210045833
# Running Gradient Descent. Current cost function is  42.96548630117102
# Running Gradient Descent. Current cost function is  42.95944611296639
# Running Gradient Descent. Current cost function is  42.95349083943976
# Running Gradient Descent. Current cost function is  42.94761977577984
# Running Gradient Descent. Current cost function is  42.94183220918665
# Running Gradient Descent. Current cost function is  42.936127419288496
# Running Gradient Descent. Current cost function is  42.93050467855745
# Running Gradient Descent. Current cost function is  42.92496325272295
# Running Gradient Descent. Current cost function is  42.91950240118306
# Running Gradient Descent. Current cost function is  42.91412137741303
# Running Gradient Descent. Current cost function is  42.90881942937072
# Running Gradient Descent. Current cost function is  42.90359579989851
# Running Gradient Descent. Current cost function is  42.89844972712134
# Running Gradient Descent. Current cost function is  42.893380444840574
# Running Gradient Descent. Current cost function is  42.88838718292329
# Running Gradient Descent. Current cost function is  42.88346916768668
# Running Gradient Descent. Current cost function is  42.87862562227734
# Running Gradient Descent. Current cost function is  42.87385576704506
# Running Gradient Descent. Current cost function is  42.86915881991091
# Running Gradient Descent. Current cost function is  42.86453399672939
# Running Gradient Descent. Current cost function is  42.859980511644316
# Running Gradient Descent. Current cost function is  42.855497577438285
# Running Gradient Descent. Current cost function is  42.851084405875575
# Running Gradient Descent. Current cost function is  42.84674020803814
# Running Gradient Descent. Current cost function is  42.842464194654674
# Running Gradient Descent. Current cost function is  42.8382555764225
# Running Gradient Descent. Current cost function is  42.83411356432216
# Running Gradient Descent. Current cost function is  42.83003736992463
# Running Gradient Descent. Current cost function is  42.826026205690965
# Running Gradient Descent. Current cost function is  42.82207928526432
# Running Gradient Descent. Current cost function is  42.818195823754316
# Running Gradient Descent. Current cost function is  42.81437503801355
# Running Gradient Descent. Current cost function is  42.81061614690633
# Running Gradient Descent. Current cost function is  42.80691837156948
# Running Gradient Descent. Current cost function is  42.80328093566531
# Running Gradient Descent. Current cost function is  42.799703065626595
# Running Gradient Descent. Current cost function is  42.7961839908936
# Running Gradient Descent. Current cost function is  42.79272294414326
# Running Gradient Descent. Current cost function is  42.789319161510335
# Running Gradient Descent. Current cost function is  42.78597188280079
# Running Gradient Descent. Current cost function is  42.78268035169719
# Running Gradient Descent. Current cost function is  42.7794438159564
# Running Gradient Descent. Current cost function is  42.7762615275994
# Running Gradient Descent. Current cost function is  42.77313274309355
# Running Gradient Descent. Current cost function is  42.77005672352704
# Running Gradient Descent. Current cost function is  42.76703273477599
# Running Gradient Descent. Current cost function is  42.76406004766388
# Running Gradient Descent. Current cost function is  42.761137938113784
# Running Gradient Descent. Current cost function is  42.75826568729313
# Running Gradient Descent. Current cost function is  42.7554425817515
# Running Gradient Descent. Current cost function is  42.75266791355114
# Running Gradient Descent. Current cost function is  42.74994098039066
# Running Gradient Descent. Current cost function is  42.74726108572183
# Running Gradient Descent. Current cost function is  42.744627538859675
# Running Gradient Descent. Current cost function is  42.74203965508595
# Running Gradient Descent. Current cost function is  42.73949675574617
# Running Gradient Descent. Current cost function is  42.736998168340314
# Running Gradient Descent. Current cost function is  42.7345432266073
# Running Gradient Descent. Current cost function is  42.73213127060342
# Running Gradient Descent. Current cost function is  42.72976164677482
# Running Gradient Descent. Current cost function is  42.727433708024236
# Running Gradient Descent. Current cost function is  42.725146813772064
# Running Gradient Descent. Current cost function is  42.72290033001191
# Running Gradient Descent. Current cost function is  42.720693629360824
# Running Gradient Descent. Current cost function is  42.718526091104316
# Running Gradient Descent. Current cost function is  42.71639710123624
# Running Gradient Descent. Current cost function is  42.71430605249386
# Running Gradient Descent. Current cost function is  42.71225234438806
# Running Gradient Descent. Current cost function is  42.710235383228934
# Running Gradient Descent. Current cost function is  42.70825458214689
# Running Gradient Descent. Current cost function is  42.70630936110943
# Running Gradient Descent. Current cost function is  42.7043991469337
# Running Gradient Descent. Current cost function is  42.702523373294945
# Running Gradient Descent. Current cost function is  42.70068148073108
# Running Gradient Descent. Current cost function is  42.69887291664348
# Running Gradient Descent. Current cost function is  42.69709713529409
# Running Gradient Descent. Current cost function is  42.695353597799
# Running Gradient Descent. Current cost function is  42.69364177211869
# Running Gradient Descent. Current cost function is  42.69196113304497
# Running Gradient Descent. Current cost function is  42.69031116218483
# Running Gradient Descent. Current cost function is  42.688691347941266
# Running Gradient Descent. Current cost function is  42.68710118549126
# Running Gradient Descent. Current cost function is  42.68554017676099
# Running Gradient Descent. Current cost function is  42.6840078303984
# Running Gradient Descent. Current cost function is  42.682503661743276
# Running Gradient Descent. Current cost function is  42.68102719279495
# Running Gradient Descent. Current cost function is  42.67957795217764
# Running Gradient Descent. Current cost function is  42.67815547510369
# Running Gradient Descent. Current cost function is  42.676759303334734
# Running Gradient Descent. Current cost function is  42.67538898514085
# Running Gradient Descent. Current cost function is  42.674044075257925
# Running Gradient Descent. Current cost function is  42.6727241348432
# Running Gradient Descent. Current cost function is  42.6714287314292
# Running Gradient Descent. Current cost function is  42.67015743887607
# Running Gradient Descent. Current cost function is  42.668909837322445
# Running Gradient Descent. Current cost function is  42.667685513134984
# Running Gradient Descent. Current cost function is  42.6664840588565
# Running Gradient Descent. Current cost function is  42.66530507315301
# Running Gradient Descent. Current cost function is  42.664148160759545
# Running Gradient Descent. Current cost function is  42.663012932425
# Running Gradient Descent. Current cost function is  42.66189900485595
# Running Gradient Descent. Current cost function is  42.66080600065959
# Running Gradient Descent. Current cost function is  42.659733548285885
# Running Gradient Descent. Current cost function is  42.65868128196891
# Running Gradient Descent. Current cost function is  42.65764884166751
# Running Gradient Descent. Current cost function is  42.65663587300542
# Running Gradient Descent. Current cost function is  42.65564202721072
# Running Gradient Descent. Current cost function is  42.654666961054836
# Running Gradient Descent. Current cost function is  42.65371033679114
# Running Gradient Descent. Current cost function is  42.65277182209311
# Running Gradient Descent. Current cost function is  42.65185108999217
# Running Gradient Descent. Current cost function is  42.650947818815325
# Running Gradient Descent. Current cost function is  42.650061692122456
# Running Gradient Descent. Current cost function is  42.64919239864354
# Running Gradient Descent. Current cost function is  42.64833963221566
# Running Gradient Descent. Current cost function is  42.64750309171998
# Running Gradient Descent. Current cost function is  42.646682481018686
# Running Gradient Descent. Current cost function is  42.64587750889184
# Running Gradient Descent. Current cost function is  42.645087888974366
# Running Gradient Descent. Current cost function is  42.64431333969304
# Running Gradient Descent. Current cost function is  42.64355358420364
# Running Gradient Descent. Current cost function is  42.64280835032815
# Running Gradient Descent. Current cost function is  42.64207737049229
# Running Gradient Descent. Current cost function is  42.641360381663034
# Running Gradient Descent. Current cost function is  42.64065712528659
# Running Gradient Descent. Current cost function is  42.63996734722645
# Running Gradient Descent. Current cost function is  42.63929079770184
# Running Gradient Descent. Current cost function is  42.638627231226444
# Running Gradient Descent. Current cost function is  42.637976406547445
# Running Gradient Descent. Current cost function is  42.63733808658495
# Running Gradient Descent. Current cost function is  42.63671203837177
# Running Gradient Descent. Current cost function is  42.63609803299363
# Running Gradient Descent. Current cost function is  42.635495845529746
# Running Gradient Descent. Current cost function is  42.63490525499388
# Running Gradient Descent. Current cost function is  42.634326044275795
# Running Gradient Descent. Current cost function is  42.633758000083226
# Running Gradient Descent. Current cost function is  42.63320091288429
# Running Gradient Descent. Current cost function is  42.63265457685041
# Running Gradient Descent. Current cost function is  42.63211878979974
# Running Gradient Descent. Current cost function is  42.63159335314106
# Running Gradient Descent. Current cost function is  42.63107807181828
# Running Gradient Descent. Current cost function is  42.63057275425541
# Running Gradient Descent. Current cost function is  42.6300772123021
# Running Gradient Descent. Current cost function is  42.62959126117972
# Running Gradient Descent. Current cost function is  42.62911471942804
# Running Gradient Descent. Current cost function is  42.62864740885238
# Running Gradient Descent. Current cost function is  42.628189154471464
# Running Gradient Descent. Current cost function is  42.62773978446574
# Running Gradient Descent. Current cost function is  42.62729913012631
# Running Gradient Descent. Current cost function is  42.62686702580449
# Running Gradient Descent. Current cost function is  42.62644330886192
# Running Gradient Descent. Current cost function is  42.62602781962124
# Running Gradient Descent. Current cost function is  42.625620401317434
# Running Gradient Descent. Current cost function is  42.625220900049676
# Running Gradient Descent. Current cost function is  42.62482916473386
# Running Gradient Descent. Current cost function is  42.62444504705569
# Running Gradient Descent. Current cost function is  42.62406840142434
# Running Gradient Descent. Current cost function is  42.62369908492676
# Running Gradient Descent. Current cost function is  42.62333695728257
# Running Gradient Descent. Current cost function is  42.6229818807995
# Running Gradient Descent. Current cost function is  42.62263372032952
# Running Gradient Descent. Current cost function is  42.62229234322546
# Running Gradient Descent. Current cost function is  42.62195761929833
# Running Gradient Descent. Current cost function is  42.6216294207751
# Running Gradient Descent. Current cost function is  42.62130762225721
# Running Gradient Descent. Current cost function is  42.620992100679565
# Running Gradient Descent. Current cost function is  42.62068273527014
# Running Gradient Descent. Current cost function is  42.62037940751017
# Running Gradient Descent. Current cost function is  42.62008200109495
# Running Gradient Descent. Current cost function is  42.61979040189512
# Running Gradient Descent. Current cost function is  42.619504497918605
# Running Gradient Descent. Current cost function is  42.619224179273054
# Running Gradient Descent. Current cost function is  42.61894933812892
# Running Gradient Descent. Current cost function is  42.61867986868299
# Running Gradient Descent. Current cost function is  42.61841566712256
# Running Gradient Descent. Current cost function is  42.61815663159011
# Running Gradient Descent. Current cost function is  42.617902662148516
# Running Gradient Descent. Current cost function is  42.61765366074683
# Running Gradient Descent. Current cost function is  42.61740953118659
# Running Gradient Descent. Current cost function is  42.617170179088596
# Running Gradient Descent. Current cost function is  42.616935511860305
# Running Gradient Descent. Current cost function is  42.61670543866366
# Running Gradient Descent. Current cost function is  42.61647987038348
# Running Gradient Descent. Current cost function is  42.616258719596324
# Running Gradient Descent. Current cost function is  42.6160419005399
# Running Gradient Descent. Current cost function is  42.61582932908289
# Running Gradient Descent. Current cost function is  42.61562092269538
# Running Gradient Descent. Current cost function is  42.61541660041962
# Running Gradient Descent. Current cost function is  42.61521628284144
# Running Gradient Descent. Current cost function is  42.61501989206198
# Running Gradient Descent. Current cost function is  42.61482735166999
# Running Gradient Descent. Current cost function is  42.61463858671454
# Running Gradient Descent. Current cost function is  42.61445352367819
# Running Gradient Descent. Current cost function is  42.61427209045066
# Running Gradient Descent. Current cost function is  42.614094216302846
# Running Gradient Descent. Current cost function is  42.61391983186136
# Running Gradient Descent. Current cost function is  42.61374886908347
# Running Gradient Descent. Current cost function is  42.613581261232476
# Running Gradient Descent. Current cost function is  42.613416942853476
# Running Gradient Descent. Current cost function is  42.61325584974958
# Running Gradient Descent. Current cost function is  42.61309791895853
# Running Gradient Descent. Current cost function is  42.612943088729715
# Running Gradient Descent. Current cost function is  42.61279129850155
# Running Gradient Descent. Current cost function is  42.612642488879324
# Running Gradient Descent. Current cost function is  42.61249660161338
# Running Gradient Descent. Current cost function is  42.61235357957766
# Running Gradient Descent. Current cost function is  42.61221336674868
# Running Gradient Descent. Current cost function is  42.61207590818484
# Running Gradient Descent. Current cost function is  42.6119411500061
# Running Gradient Descent. Current cost function is  42.611809039374016
# Running Gradient Descent. Current cost function is  42.61167952447212
# Running Gradient Descent. Current cost function is  42.611552554486714
# Running Gradient Descent. Current cost function is  42.61142807958788
# Running Gradient Descent. Current cost function is  42.61130605091094
# Running Gradient Descent. Current cost function is  42.6111864205382
# Running Gradient Descent. Current cost function is  42.611069141481046
# Running Gradient Descent. Current cost function is  42.61095416766231
# Running Gradient Descent. Current cost function is  42.610841453899
# Running Gradient Descent. Current cost function is  42.61073095588535
# Running Gradient Descent. Current cost function is  42.61062263017614
# Running Gradient Descent. Current cost function is  42.610516434170314
# Running Gradient Descent. Current cost function is  42.610412326094945
# Running Gradient Descent. Current cost function is  42.610310264989444
# Running Gradient Descent. Current cost function is  42.610210210690084
# Running Gradient Descent. Current cost function is  42.61011212381477
# Running Gradient Descent. Current cost function is  42.61001596574817
# Running Gradient Descent. Current cost function is  42.60992169862697
# Running Gradient Descent. Current cost function is  42.609829285325596
# Running Gradient Descent. Current cost function is  42.60973868944201
# Running Gradient Descent. Current cost function is  42.60964987528391
# Running Gradient Descent. Current cost function is  42.60956280785507
# Running Gradient Descent. Current cost function is  42.60947745284204
# Running Gradient Descent. Current cost function is  42.60939377660101
# Running Gradient Descent. Current cost function is  42.60931174614494
# Running Gradient Descent. Current cost function is  42.60923132913097
# Running Gradient Descent. Current cost function is  42.609152493848
# Running Gradient Descent. Current cost function is  42.60907520920454
# Running Gradient Descent. Current cost function is  42.608999444716765
# Running Gradient Descent. Current cost function is  42.608925170496846
# Running Gradient Descent. Current cost function is  42.608852357241396
# Running Gradient Descent. Current cost function is  42.608780976220245
# Running Gradient Descent. Current cost function is  42.60871099926536
# Running Gradient Descent. Current cost function is  42.608642398759976
# Running Gradient Descent. Current cost function is  42.60857514762794
# Running Gradient Descent. Current cost function is  42.60850921932329
# Running Gradient Descent. Current cost function is  42.608444587819946
# Running Gradient Descent. Current cost function is  42.6083812276017
# Running Gradient Descent. Current cost function is  42.6083191136523
# Running Gradient Descent. Current cost function is  42.608258221445794
# Running Gradient Descent. Current cost function is  42.608198526937
# Running Gradient Descent. Current cost function is  42.6081400065522
# Running Gradient Descent. Current cost function is  42.60808263717997
# Running Gradient Descent. Current cost function is  42.60802639616223
# Running Gradient Descent. Current cost function is  42.60797126128544
# Running Gradient Descent. Current cost function is  42.60791721077194
# Running Gradient Descent. Current cost function is  42.60786422327148
# Running Gradient Descent. Current cost function is  42.607812277852936
# Running Gradient Descent. Current cost function is  42.60776135399613
# Running Gradient Descent. Current cost function is  42.60771143158385
# Running Gradient Descent. Current cost function is  42.607662490893986
# Running Gradient Descent. Current cost function is  42.60761451259185
# Running Gradient Descent. Current cost function is  42.60756747772261
# Running Gradient Descent. Current cost function is  42.60752136770392
# Running Gradient Descent. Current cost function is  42.607476164318605
# Running Gradient Descent. Current cost function is  42.60743184970761
# Running Gradient Descent. Current cost function is  42.60738840636293
# Running Gradient Descent. Current cost function is  42.60734581712082
# Running Gradient Descent. Current cost function is  42.60730406515506
# Running Gradient Descent. Current cost function is  42.60726313397035
# Running Gradient Descent. Current cost function is  42.60722300739584
# Running Gradient Descent. Current cost function is  42.6071836695788
# Running Gradient Descent. Current cost function is  42.60714510497842
# Running Gradient Descent. Current cost function is  42.60710729835969
# Running Gradient Descent. Current cost function is  42.6070702347874
# Running Gradient Descent. Current cost function is  42.60703389962032
# Running Gradient Descent. Current cost function is  42.606998278505394
# Running Gradient Descent. Current cost function is  42.60696335737216
# Running Gradient Descent. Current cost function is  42.606929122427154
# Running Gradient Descent. Current cost function is  42.60689556014852
# Running Gradient Descent. Current cost function is  42.60686265728071
# Running Gradient Descent. Current cost function is  42.60683040082919
# Running Gradient Descent. Current cost function is  42.606798778055406
# Running Gradient Descent. Current cost function is  42.60676777647173
# Running Gradient Descent. Current cost function is  42.60673738383652
# Running Gradient Descent. Current cost function is  42.606707588149334
# Running Gradient Descent. Current cost function is  42.60667837764618
# Running Gradient Descent. Current cost function is  42.60664974079488
# Running Gradient Descent. Current cost function is  42.606621666290486
# Running Gradient Descent. Current cost function is  42.606594143050884
# Running Gradient Descent. Current cost function is  42.60656716021237
# Running Gradient Descent. Current cost function is  42.60654070712539
# Running Gradient Descent. Current cost function is  42.60651477335029
# Running Gradient Descent. Current cost function is  42.606489348653255
# Running Gradient Descent. Current cost function is  42.6064644230022
# Running Gradient Descent. Current cost function is  42.60643998656286
# Running Gradient Descent. Current cost function is  42.60641602969487
# Running Gradient Descent. Current cost function is  42.60639254294796
# Running Gradient Descent. Current cost function is  42.606369517058205
# Running Gradient Descent. Current cost function is  42.606346942944405
# Running Gradient Descent. Current cost function is  42.60632481170443
# Running Gradient Descent. Current cost function is  42.60630311461174
# Running Gradient Descent. Current cost function is  42.606281843111915
# Running Gradient Descent. Current cost function is  42.606260988819265
# Running Gradient Descent. Current cost function is  42.60624054351353
# Running Gradient Descent. Current cost function is  42.606220499136576
# Running Gradient Descent. Current cost function is  42.60620084778928
# Running Gradient Descent. Current cost function is  42.606181581728315
# Running Gradient Descent. Current cost function is  42.60616269336314
# Running Gradient Descent. Current cost function is  42.606144175252965
# Running Gradient Descent. Current cost function is  42.60612602010382
# Running Gradient Descent. Current cost function is  42.60610822076565
# Running Gradient Descent. Current cost function is  42.60609077022947
# Running Gradient Descent. Current cost function is  42.60607366162461
# Running Gradient Descent. Current cost function is  42.60605688821597
# Running Gradient Descent. Current cost function is  42.60604044340135
# Running Gradient Descent. Current cost function is  42.60602432070885
# Running Gradient Descent. Current cost function is  42.60600851379427
# Running Gradient Descent. Current cost function is  42.60599301643863
# Running Gradient Descent. Current cost function is  42.60597782254566
# Running Gradient Descent. Current cost function is  42.60596292613941
# Running Gradient Descent. Current cost function is  42.60594832136188
# Running Gradient Descent. Current cost function is  42.60593400247066
# Running Gradient Descent. Current cost function is  42.60591996383669
# Running Gradient Descent. Current cost function is  42.605906199942005
# Running Gradient Descent. Current cost function is  42.60589270537753
# Running Gradient Descent. Current cost function is  42.60587947484096
# Running Gradient Descent. Current cost function is  42.605866503134656
# Running Gradient Descent. Current cost function is  42.60585378516354
# Running Gradient Descent. Current cost function is  42.6058413159331
# Running Gradient Descent. Current cost function is  42.6058290905474
# Running Gradient Descent. Current cost function is  42.60581710420716
# Running Gradient Descent. Current cost function is  42.6058053522078
# Running Gradient Descent. Current cost function is  42.6057938299376
# Running Gradient Descent. Current cost function is  42.60578253287587
# Running Gradient Descent. Current cost function is  42.605771456591135
# Running Gradient Descent. Current cost function is  42.60576059673939
# Running Gradient Descent. Current cost function is  42.60574994906236
# Running Gradient Descent. Current cost function is  42.60573950938583
# Running Gradient Descent. Current cost function is  42.60572927361795
# Running Gradient Descent. Current cost function is  42.605719237747664
# Running Gradient Descent. Current cost function is  42.605709397843036
# Running Gradient Descent. Current cost function is  42.60569975004975
# Running Gradient Descent. Current cost function is  42.60569029058957
# Running Gradient Descent. Current cost function is  42.605681015758805
# Running Gradient Descent. Current cost function is  42.60567192192687
# Running Gradient Descent. Current cost function is  42.60566300553482
# Running Gradient Descent. Current cost function is  42.60565426309396
# Running Gradient Descent. Current cost function is  42.60564569118443
# Running Gradient Descent. Current cost function is  42.60563728645385
# Running Gradient Descent. Current cost function is  42.605629045616006
# Running Gradient Descent. Current cost function is  42.60562096544953
# Running Gradient Descent. Current cost function is  42.60561304279663
# Running Gradient Descent. Current cost function is  42.605605274561796
# Running Gradient Descent. Current cost function is  42.60559765771062
# Running Gradient Descent. Current cost function is  42.605590189268554
# Running Gradient Descent. Current cost function is  42.60558286631976
# Running Gradient Descent. Current cost function is  42.605575686005906
# Running Gradient Descent. Current cost function is  42.60556864552506
# Running Gradient Descent. Current cost function is  42.60556174213059
# Running Gradient Descent. Current cost function is  42.60555497313001
# Running Gradient Descent. Current cost function is  42.605548335883995
# Running Gradient Descent. Current cost function is  42.605541827805254
# Running Gradient Descent. Current cost function is  42.60553544635754
# Running Gradient Descent. Current cost function is  42.60552918905466
# Running Gradient Descent. Current cost function is  42.605523053459414
# Running Gradient Descent. Current cost function is  42.60551703718272
# Running Gradient Descent. Current cost function is  42.6055111378826
# Running Gradient Descent. Current cost function is  42.60550535326327
# Running Gradient Descent. Current cost function is  42.6054996810742
# Running Gradient Descent. Current cost function is  42.605494119109274
# Running Gradient Descent. Current cost function is  42.605488665205876
# Running Gradient Descent. Current cost function is  42.605483317244015
# Running Gradient Descent. Current cost function is  42.60547807314554
# Running Gradient Descent. Current cost function is  42.60547293087323
# Running Gradient Descent. Current cost function is  42.60546788843008
# Running Gradient Descent. Current cost function is  42.60546294385842
# Running Gradient Descent. Current cost function is  42.6054580952392
# Running Gradient Descent. Current cost function is  42.60545334069119
# Running Gradient Descent. Current cost function is  42.60544867837025
# Running Gradient Descent. Current cost function is  42.605444106468596
# Running Gradient Descent. Current cost function is  42.60543962321407
# Running Gradient Descent. Current cost function is  42.60543522686944
# Running Gradient Descent. Current cost function is  42.60543091573172
# Running Gradient Descent. Current cost function is  42.60542668813151
# Running Gradient Descent. Current cost function is  42.60542254243226
# Running Gradient Descent. Current cost function is  42.60541847702971
# Running Gradient Descent. Current cost function is  42.60541449035119
# Running Gradient Descent. Current cost function is  42.605410580855036
# Running Gradient Descent. Current cost function is  42.60540674702994
# Running Gradient Descent. Current cost function is  42.60540298739438
# Running Gradient Descent. Current cost function is  42.605399300496025
# Running Gradient Descent. Current cost function is  42.60539568491114
# Running Gradient Descent. Current cost function is  42.60539213924404
# Running Gradient Descent. Current cost function is  42.605388662126536
# Running Gradient Descent. Current cost function is  42.60538525221738
# Running Gradient Descent. Current cost function is  42.60538190820174
# Running Gradient Descent. Current cost function is  42.60537862879069
# Running Gradient Descent. Current cost function is  42.60537541272066
# Running Gradient Descent. Current cost function is  42.60537225875297
# Running Gradient Descent. Current cost function is  42.60536916567335
# Running Gradient Descent. Current cost function is  42.6053661322914
# Running Gradient Descent. Current cost function is  42.60536315744018
# Running Gradient Descent. Current cost function is  42.60536023997571
# Running Gradient Descent. Current cost function is  42.60535737877653
# Running Gradient Descent. Current cost function is  42.60535457274325
# Running Gradient Descent. Current cost function is  42.605351820798134
# Running Gradient Descent. Current cost function is  42.60534912188463
# Running Gradient Descent. Current cost function is  42.605346474966986
# Running Gradient Descent. Current cost function is  42.60534387902984
# Running Gradient Descent. Current cost function is  42.60534133307778
# Running Gradient Descent. Current cost function is  42.60533883613501
# Running Gradient Descent. Current cost function is  42.60533638724491
# Running Gradient Descent. Current cost function is  42.605333985469684
# Running Gradient Descent. Current cost function is  42.605331629889974
# Running Gradient Descent. Current cost function is  42.6053293196045
# Running Gradient Descent. Current cost function is  42.605327053729724
# Running Gradient Descent. Current cost function is  42.605324831399464
# Running Gradient Descent. Current cost function is  42.60532265176457
# Running Gradient Descent. Current cost function is  42.605320513992595
# Running Gradient Descent. Current cost function is  42.605318417267455
# Running Gradient Descent. Current cost function is  42.605316360789104
# Running Gradient Descent. Current cost function is  42.60531434377322
# Running Gradient Descent. Current cost function is  42.6053123654509
# Running Gradient Descent. Current cost function is  42.60531042506834
# Running Gradient Descent. Current cost function is  42.60530852188656
# Running Gradient Descent. Current cost function is  42.60530665518111
# Running Gradient Descent. Current cost function is  42.60530482424174
# Running Gradient Descent. Current cost function is  42.60530302837218
# Running Gradient Descent. Current cost function is  42.60530126688982
# Running Gradient Descent. Current cost function is  42.60529953912547
# Running Gradient Descent. Current cost function is  42.60529784442307
# Running Gradient Descent. Current cost function is  42.60529618213946
# Running Gradient Descent. Current cost function is  42.605294551644086
# Running Gradient Descent. Current cost function is  42.60529295231878
# Running Gradient Descent. Current cost function is  42.60529138355752
# Running Gradient Descent. Current cost function is  42.605289844766176
# Running Gradient Descent. Current cost function is  42.605288335362275
# Running Gradient Descent. Current cost function is  42.60528685477476
# Running Gradient Descent. Current cost function is  42.60528540244381
# Running Gradient Descent. Current cost function is  42.60528397782057
# Running Gradient Descent. Current cost function is  42.605282580366946
# Running Gradient Descent. Current cost function is  42.60528120955542
# Running Gradient Descent. Current cost function is  42.6052798648688
# Running Gradient Descent. Current cost function is  42.605278545800054
# Running Gradient Descent. Current cost function is  42.60527725185207
# Running Gradient Descent. Current cost function is  42.60527598253751
# Running Gradient Descent. Current cost function is  42.605274737378586
# Running Gradient Descent. Current cost function is  42.60527351590685
# Running Gradient Descent. Current cost function is  42.605272317663065
# Running Gradient Descent. Current cost function is  42.605271142196976
# Running Gradient Descent. Current cost function is  42.60526998906716
# Running Gradient Descent. Current cost function is  42.60526885784085
# Running Gradient Descent. Current cost function is  42.60526774809374
# Running Gradient Descent. Current cost function is  42.60526665940984
# Running Gradient Descent. Current cost function is  42.605265591381325
# Running Gradient Descent. Current cost function is  42.605264543608335
# Running Gradient Descent. Current cost function is  42.60526351569886
# Running Gradient Descent. Current cost function is  42.605262507268534
# Running Gradient Descent. Current cost function is  42.605261517940555
# Running Gradient Descent. Current cost function is  42.605260547345466
# Running Gradient Descent. Current cost function is  42.605259595121055
# Running Gradient Descent. Current cost function is  42.6052586609122
# Running Gradient Descent. Current cost function is  42.60525774437072
# Running Gradient Descent. Current cost function is  42.60525684515524
# Running Gradient Descent. Current cost function is  42.605255962931075
# Running Gradient Descent. Current cost function is  42.60525509737008
# Running Gradient Descent. Current cost function is  42.605254248150544
# Running Gradient Descent. Current cost function is  42.60525341495701
# Running Gradient Descent. Current cost function is  42.605252597480224
# Running Gradient Descent. Current cost function is  42.60525179541695
# Running Gradient Descent. Current cost function is  42.6052510084699
# Running Gradient Descent. Current cost function is  42.60525023634758
# Running Gradient Descent. Current cost function is  42.6052494787642
# Running Gradient Descent. Current cost function is  42.60524873543956
# Running Gradient Descent. Current cost function is  42.60524800609891
# Running Gradient Descent. Current cost function is  42.60524729047289
# Running Gradient Descent. Current cost function is  42.60524658829738
# Running Gradient Descent. Current cost function is  42.60524589931344
# Running Gradient Descent. Current cost function is  42.60524522326716
# Running Gradient Descent. Current cost function is  42.60524455990961
# Running Gradient Descent. Current cost function is  42.60524390899669
# Running Gradient Descent. Current cost function is  42.60524327028909
# Running Gradient Descent. Current cost function is  42.605242643552145
# Running Gradient Descent. Current cost function is  42.60524202855579
# Running Gradient Descent. Current cost function is  42.60524142507443
# Running Gradient Descent. Current cost function is  42.605240832886885
# Running Gradient Descent. Current cost function is  42.605240251776266
# Running Gradient Descent. Current cost function is  42.60523968152993
# Running Gradient Descent. Current cost function is  42.60523912193936
# Running Gradient Descent. Current cost function is  42.60523857280013
# Running Gradient Descent. Current cost function is  42.605238033911775
# Running Gradient Descent. Current cost function is  42.60523750507773
# Running Gradient Descent. Current cost function is  42.60523698610528
# Running Gradient Descent. Current cost function is  42.605236476805445
# Running Gradient Descent. Current cost function is  42.60523597699294
# Running Gradient Descent. Current cost function is  42.605235486486066
# Running Gradient Descent. Current cost function is  42.60523500510668
# Running Gradient Descent. Current cost function is  42.60523453268009
# Running Gradient Descent. Current cost function is  42.60523406903503
# Running Gradient Descent. Current cost function is  42.60523361400352
# Running Gradient Descent. Current cost function is  42.60523316742088
# Running Gradient Descent. Current cost function is  42.605232729125625
# Running Gradient Descent. Current cost function is  42.605232298959415
# Running Gradient Descent. Current cost function is  42.60523187676698
# Running Gradient Descent. Current cost function is  42.60523146239606
# Running Gradient Descent. Current cost function is  42.605231055697374
# Running Gradient Descent. Current cost function is  42.60523065652452
# Running Gradient Descent. Current cost function is  42.605230264733954
# Running Gradient Descent. Current cost function is  42.60522988018491
# Running Gradient Descent. Current cost function is  42.60522950273936
# Running Gradient Descent. Current cost function is  42.605229132261954
# Running Gradient Descent. Current cost function is  42.60522876861997
# Running Gradient Descent. Current cost function is  42.60522841168326
# Running Gradient Descent. Current cost function is  42.6052280613242
# Running Gradient Descent. Current cost function is  42.60522771741763
# Running Gradient Descent. Current cost function is  42.60522737984084
# Running Gradient Descent. Current cost function is  42.60522704847348
# Running Gradient Descent. Current cost function is  42.605226723197546
# Running Gradient Descent. Current cost function is  42.60522640389731
# Running Gradient Descent. Current cost function is  42.6052260904593
# Running Gradient Descent. Current cost function is  42.60522578277221
# Running Gradient Descent. Current cost function is  42.60522548072692
# Running Gradient Descent. Current cost function is  42.60522518421643
# Running Gradient Descent. Current cost function is  42.60522489313577
# Running Gradient Descent. Current cost function is  42.60522460738204
# Running Gradient Descent. Current cost function is  42.60522432685431
# Running Gradient Descent. Current cost function is  42.60522405145362
# Running Gradient Descent. Current cost function is  42.6052237810829
# Running Gradient Descent. Current cost function is  42.605223515646976
# Running Gradient Descent. Current cost function is  42.6052232550525
# Running Gradient Descent. Current cost function is  42.605222999207946
# Running Gradient Descent. Current cost function is  42.60522274802353
# Running Gradient Descent. Current cost function is  42.60522250141123
# Running Gradient Descent. Current cost function is  42.6052222592847
# Running Gradient Descent. Current cost function is  42.60522202155928
# Running Gradient Descent. Current cost function is  42.60522178815193
# Running Gradient Descent. Current cost function is  42.60522155898121
# Running Gradient Descent. Current cost function is  42.60522133396728
# Running Gradient Descent. Current cost function is  42.6052211130318
# Running Gradient Descent. Current cost function is  42.60522089609796
# Running Gradient Descent. Current cost function is  42.60522068309044
# Running Gradient Descent. Current cost function is  42.60522047393535
# Running Gradient Descent. Current cost function is  42.60522026856023
# Running Gradient Descent. Current cost function is  42.605220066894034
# Running Gradient Descent. Current cost function is  42.60521986886706
# Running Gradient Descent. Current cost function is  42.605219674410954
# Running Gradient Descent. Current cost function is  42.60521948345868
# Running Gradient Descent. Current cost function is  42.60521929594451
# Running Gradient Descent. Current cost function is  42.60521911180394
# Running Gradient Descent. Current cost function is  42.60521893097374
# Running Gradient Descent. Current cost function is  42.60521875339188
# Running Gradient Descent. Current cost function is  42.60521857899753
# Running Gradient Descent. Current cost function is  42.60521840773102
# Running Gradient Descent. Current cost function is  42.60521823953383
# Running Gradient Descent. Current cost function is  42.605218074348564
# Running Gradient Descent. Current cost function is  42.60521791211893
# Running Gradient Descent. Current cost function is  42.60521775278972
# Running Gradient Descent. Current cost function is  42.605217596306765
# Running Gradient Descent. Current cost function is  42.605217442616954
# Running Gradient Descent. Current cost function is  42.6052172916682
# Running Gradient Descent. Current cost function is  42.60521714340938
# Running Gradient Descent. Current cost function is  42.60521699779039
# Running Gradient Descent. Current cost function is  42.60521685476207
# Running Gradient Descent. Current cost function is  42.60521671427619
# Running Gradient Descent. Current cost function is  42.60521657628546
# Running Gradient Descent. Current cost function is  42.60521644074349
# Running Gradient Descent. Current cost function is  42.60521630760477
# Running Gradient Descent. Current cost function is  42.60521617682467
# Running Gradient Descent. Current cost function is  42.60521604835941
# Running Gradient Descent. Current cost function is  42.60521592216604
# Running Gradient Descent. Current cost function is  42.60521579820244
# Running Gradient Descent. Current cost function is  42.60521567642729
# Running Gradient Descent. Current cost function is  42.605215556800054
# ...
# Running Gradient Descent. Current cost function is  42.605210127639225
# Running Gradient Descent. Current cost function is  42.605210102504216
# Running Gradient Descent. Current cost function is  42.60521007776901
# Running Gradient Descent. Current cost function is  42.60521005342674
# Running Gradient Descent. Current cost function is  42.60521002947064
# Running Gradient Descent. Current cost function is  42.605210005894094
# Running Gradient Descent. Current cost function is  42.60520998269059
# Running Gradient Descent. Current cost function is  42.60520995985373
# Running Gradient Descent. Current cost function is  42.60520993737725
# Running Gradient Descent. Current cost function is  42.605209915254996
# Running Gradient Descent. Current cost function is  42.605209893480904
# Running Gradient Descent. Current cost function is  42.60520987204904
# Running Gradient Descent. Current cost function is  42.605209850953564
# Running Gradient Descent. Current cost function is  42.60520983018877
# Running Gradient Descent. Current cost function is  42.60520980974902
# Running Gradient Descent. Current cost function is  42.6052097896288
# Running Gradient Descent. Current cost function is  42.60520976982268
# Running Gradient Descent. Current cost function is  42.60520975032535
# Running Gradient Descent. Current cost function is  42.605209731131566
# Running Gradient Descent. Current cost function is  42.60520971223621
# Running Gradient Descent. Current cost function is  42.60520969363422
# Running Gradient Descent. Current cost function is  42.60520967532067
# Running Gradient Descent. Current cost function is  42.605209657290686
# Running Gradient Descent. Current cost function is  42.605209639539495
# Running Gradient Descent. Current cost function is  42.605209622062404
# Running Gradient Descent. Current cost function is  42.605209604854814
# Running Gradient Descent. Current cost function is  42.60520958791219
# Running Gradient Descent. Current cost function is  42.60520957123011
# Running Gradient Descent. Current cost function is  42.605209554804205
# Running Gradient Descent. Current cost function is  42.605209538630184
# Running Gradient Descent. Current cost function is  42.605209522703845
# Running Gradient Descent. Current cost function is  42.60520950702106
# Running Gradient Descent. Current cost function is  42.60520949157776
# Running Gradient Descent. Current cost function is  42.60520947636996
# Running Gradient Descent. Current cost function is  42.60520946139375
# Running Gradient Descent. Current cost function is  42.605209446645276
# Running Gradient Descent. Current cost function is  42.60520943212077
# Running Gradient Descent. Current cost function is  42.60520941781652
# Running Gradient Descent. Current cost function is  42.60520940372887
# Running Gradient Descent. Current cost function is  42.60520938985425
# Running Gradient Descent. Current cost function is  42.605209376189144
# Running Gradient Descent. Current cost function is  42.60520936273009
# Running Gradient Descent. Current cost function is  42.6052093494737
# Running Gradient Descent. Current cost function is  42.605209336416635
# Running Gradient Descent. Current cost function is  42.60520932355562
# Running Gradient Descent. Current cost function is  42.605209310887446
# Running Gradient Descent. Current cost function is  42.605209298408944
# Running Gradient Descent. Current cost function is  42.60520928611701
# Running Gradient Descent. Current cost function is  42.6052092740086
# Running Gradient Descent. Current cost function is  42.60520926208071
# Running Gradient Descent. Current cost function is  42.6052092503304
# Running Gradient Descent. Current cost function is  42.60520923875477
# Running Gradient Descent. Current cost function is  42.60520922735098
# Running Gradient Descent. Current cost function is  42.60520921611625
# Running Gradient Descent. Current cost function is  42.60520920504783
# Running Gradient Descent. Current cost function is  42.605209194143015
# Running Gradient Descent. Current cost function is  42.60520918339916
# Running Gradient Descent. Current cost function is  42.60520917281367
# Running Gradient Descent. Current cost function is  42.605209162383986
# Running Gradient Descent. Current cost function is  42.60520915210759
# Running Gradient Descent. Current cost function is  42.605209141982016
# Running Gradient Descent. Current cost function is  42.60520913200484
# Running Gradient Descent. Current cost function is  42.605209122173676
# Running Gradient Descent. Current cost function is  42.60520911248618
# Running Gradient Descent. Current cost function is  42.60520910294005
# Running Gradient Descent. Current cost function is  42.60520909353303
# Running Gradient Descent. Current cost function is  42.60520908426289
# Running Gradient Descent. Current cost function is  42.60520907512744
# Running Gradient Descent. Current cost function is  42.605209066124544
# Running Gradient Descent. Current cost function is  42.60520905725209
# Running Gradient Descent. Current cost function is  42.605209048508
# Running Gradient Descent. Current cost function is  42.60520903989024
# Running Gradient Descent. Current cost function is  42.605209031396804
# Running Gradient Descent. Current cost function is  42.60520902302573
# Running Gradient Descent. Current cost function is  42.60520901477507
# Running Gradient Descent. Current cost function is  42.60520900664292
# Running Gradient Descent. Current cost function is  42.60520899862743
# Running Gradient Descent. Current cost function is  42.60520899072675
# Running Gradient Descent. Current cost function is  42.60520898293908
# Running Gradient Descent. Current cost function is  42.60520897526264
# Running Gradient Descent. Current cost function is  42.60520896769568
# Running Gradient Descent. Current cost function is  42.605208960236496
# Running Gradient Descent. Current cost function is  42.605208952883395
# Running Gradient Descent. Current cost function is  42.605208945634715
# Running Gradient Descent. Current cost function is  42.605208938488836
# Running Gradient Descent. Current cost function is  42.60520893144415
# Running Gradient Descent. Current cost function is  42.60520892449909
# Running Gradient Descent. Current cost function is  42.6052089176521
# Running Gradient Descent. Current cost function is  42.60520891090165
# Running Gradient Descent. Current cost function is  42.60520890424627
# Running Gradient Descent. Current cost function is  42.60520889768446
# Running Gradient Descent. Current cost function is  42.605208891214794
# Running Gradient Descent. Current cost function is  42.60520888483584
# Running Gradient Descent. Current cost function is  42.6052088785462
# Running Gradient Descent. Current cost function is  42.605208872344505
# Running Gradient Descent. Current cost function is  42.6052088662294
# Running Gradient Descent. Current cost function is  42.605208860199554
# Running Gradient Descent. Current cost function is  42.60520885425366
# Running Gradient Descent. Current cost function is  42.60520884839044
# Running Gradient Descent. Current cost function is  42.605208842608626
# Running Gradient Descent. Current cost function is  42.60520883690697
# Running Gradient Descent. Current cost function is  42.60520883128425
# Running Gradient Descent. Current cost function is  42.60520882573928
# Running Gradient Descent. Current cost function is  42.60520882027087
# Running Gradient Descent. Current cost function is  42.60520881487784
# Running Gradient Descent. Current cost function is  42.60520880955907
# Running Gradient Descent. Current cost function is  42.605208804313435
# Running Gradient Descent. Current cost function is  42.605208799139824
# Running Gradient Descent. Current cost function is  42.605208794037146
# Running Gradient Descent. Current cost function is  42.60520878900434
# Running Gradient Descent. Current cost function is  42.60520878404034
# Running Gradient Descent. Current cost function is  42.60520877914413
# Running Gradient Descent. Current cost function is  42.605208774314676
# Running Gradient Descent. Current cost function is  42.605208769551
# Running Gradient Descent. Current cost function is  42.60520876485209
# Running Gradient Descent. Current cost function is  42.605208760216996
# Running Gradient Descent. Current cost function is  42.60520875564476
# Running Gradient Descent. Current cost function is  42.605208751134455
# Running Gradient Descent. Current cost function is  42.60520874668514
# Running Gradient Descent. Current cost function is  42.60520874229593
# Running Gradient Descent. Current cost function is  42.60520873796592
# Running Gradient Descent. Current cost function is  42.60520873369423
# Running Gradient Descent. Current cost function is  42.605208729480005
# Running Gradient Descent. Current cost function is  42.60520872532239
# Running Gradient Descent. Current cost function is  42.60520872122056
# Running Gradient Descent. Current cost function is  42.60520871717369
# Running Gradient Descent. Current cost function is  42.60520871318096
# Running Gradient Descent. Current cost function is  42.60520870924159
# Running Gradient Descent. Current cost function is  42.60520870535478
# Running Gradient Descent. Current cost function is  42.60520870151978
# Running Gradient Descent. Current cost function is  42.60520869773581
# Running Gradient Descent. Current cost function is  42.605208694002144
# Running Gradient Descent. Current cost function is  42.605208690318044
# Running Gradient Descent. Current cost function is  42.60520868668278
# Running Gradient Descent. Current cost function is  42.60520868309565
# Running Gradient Descent. Current cost function is  42.60520867955595
# Running Gradient Descent. Current cost function is  42.60520867606299
# Running Gradient Descent. Current cost function is  42.6052086726161
# Running Gradient Descent. Current cost function is  42.60520866921461
# Running Gradient Descent. Current cost function is  42.60520866585787
# Running Gradient Descent. Current cost function is  42.60520866254522
# Running Gradient Descent. Current cost function is  42.605208659276045
# Running Gradient Descent. Current cost function is  42.605208656049705
# Running Gradient Descent. Current cost function is  42.60520865286559
# Running Gradient Descent. Current cost function is  42.605208649723096
# Running Gradient Descent. Current cost function is  42.60520864662162
# Running Gradient Descent. Current cost function is  42.60520864356058
# Running Gradient Descent. Current cost function is  42.6052086405394
# Running Gradient Descent. Current cost function is  42.60520863755752
# Running Gradient Descent. Current cost function is  42.605208634614364
# Running Gradient Descent. Current cost function is  42.60520863170939
# Running Gradient Descent. Current cost function is  42.60520862884206
# Running Gradient Descent. Current cost function is  42.60520862601183
# Running Gradient Descent. Current cost function is  42.605208623218175
# Running Gradient Descent. Current cost function is  42.605208620460594
# Running Gradient Descent. Current cost function is  42.60520861773856
# Running Gradient Descent. Current cost function is  42.60520861505159
# Running Gradient Descent. Current cost function is  42.60520861239917
# Running Gradient Descent. Current cost function is  42.605208609780824
# Running Gradient Descent. Current cost function is  42.605208607196076
# Running Gradient Descent. Current cost function is  42.605208604644446
# Running Gradient Descent. Current cost function is  42.60520860212549
# Running Gradient Descent. Current cost function is  42.60520859963873
# Running Gradient Descent. Current cost function is  42.605208597183726
# Running Gradient Descent. Current cost function is  42.605208594760036
# Running Gradient Descent. Current cost function is  42.60520859236722
# Running Gradient Descent. Current cost function is  42.60520859000486
# Running Gradient Descent. Current cost function is  42.605208587672514
# Running Gradient Descent. Current cost function is  42.60520858536979
# Running Gradient Descent. Current cost function is  42.60520858309625
# Running Gradient Descent. Current cost function is  42.60520858085152
# Running Gradient Descent. Current cost function is  42.60520857863518
# Running Gradient Descent. Current cost function is  42.60520857644684
# Running Gradient Descent. Current cost function is  42.60520857428614
# Running Gradient Descent. Current cost function is  42.60520857215267
# Running Gradient Descent. Current cost function is  42.60520857004607
# Running Gradient Descent. Current cost function is  42.60520856796597
# Running Gradient Descent. Current cost function is  42.605208565912
# Running Gradient Descent. Current cost function is  42.605208563883814
# Running Gradient Descent. Current cost function is  42.60520856188106
# Running Gradient Descent. Current cost function is  42.60520855990338
# Running Gradient Descent. Current cost function is  42.60520855795045
# Running Gradient Descent. Current cost function is  42.605208556021914
# Running Gradient Descent. Current cost function is  42.60520855411745
# Running Gradient Descent. Current cost function is  42.60520855223674
# Running Gradient Descent. Current cost function is  42.60520855037945
# Running Gradient Descent. Current cost function is  42.60520854854527
# Running Gradient Descent. Current cost function is  42.60520854673388
# Running Gradient Descent. Current cost function is  42.60520854494498
# Running Gradient Descent. Current cost function is  42.60520854317827
# Running Gradient Descent. Current cost function is  42.60520854143344
# Running Gradient Descent. Current cost function is  42.60520853971021
# Running Gradient Descent. Current cost function is  42.60520853800828
# Running Gradient Descent. Current cost function is  42.60520853632737
# Running Gradient Descent. Current cost function is  42.6052085346672
# Running Gradient Descent. Current cost function is  42.60520853302748
# Running Gradient Descent. Current cost function is  42.60520853140795
# Running Gradient Descent. Current cost function is  42.605208529808344
# Running Gradient Descent. Current cost function is  42.60520852822839
# Running Gradient Descent. Current cost function is  42.60520852666783
# Running Gradient Descent. Current cost function is  42.6052085251264
# Running Gradient Descent. Current cost function is  42.60520852360385
# Running Gradient Descent. Current cost function is  42.605208522099936
# Running Gradient Descent. Current cost function is  42.605208520614404
# Running Gradient Descent. Current cost function is  42.60520851914701
# Running Gradient Descent. Current cost function is  42.60520851769753
# Running Gradient Descent. Current cost function is  42.60520851626571
# Running Gradient Descent. Current cost function is  42.60520851485133
# Running Gradient Descent. Current cost function is  42.60520851345415
# Running Gradient Descent. Current cost function is  42.60520851207395
# Running Gradient Descent. Current cost function is  42.60520851071051
# Running Gradient Descent. Current cost function is  42.60520850936361
# Running Gradient Descent. Current cost function is  42.60520850803303
# Running Gradient Descent. Current cost function is  42.60520850671856
# Running Gradient Descent. Current cost function is  42.605208505419995
# Running Gradient Descent. Current cost function is  42.60520850413712
# Running Gradient Descent. Current cost function is  42.60520850286973
# Running Gradient Descent. Current cost function is  42.605208501617625
# Running Gradient Descent. Current cost function is  42.60520850038061
# Running Gradient Descent. Current cost function is  42.60520849915849
# Running Gradient Descent. Current cost function is  42.605208497951075
# Running Gradient Descent. Current cost function is  42.60520849675817
# Running Gradient Descent. Current cost function is  42.60520849557959
# Running Gradient Descent. Current cost function is  42.605208494415145
# Running Gradient Descent. Current cost function is  42.605208493264655
# Running Gradient Descent. Current cost function is  42.60520849212795
# Running Gradient Descent. Current cost function is  42.60520849100484

# %%
print('Our learned value of theta: ',theta.ravel())
# Out:
# Our learned value of theta:  [ 9.33345690e+03 -1.09405109e+02  1.09405109e+02 -9.50100871e+01
#  -8.45579124e+01 -7.07147448e+00  3.42495505e+01  1.82988483e+01
#   1.01010034e+02  3.64702974e+01 -1.36688356e+02 -6.83058928e+01
#   2.04059551e+02 -1.23275654e+01 -2.07318655e+00  1.25029756e+01
#  -3.04032136e+00  4.16176688e+00  4.24613234e+01 -3.08389374e+01
#  -1.40871032e+03 -4.10997879e+02  1.83447740e+02]

# %%
plt.plot(cost_values)
plt.ylabel('Cost J')
plt.xlabel('Iterations');
